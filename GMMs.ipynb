# %%
import pickle
def read_pickles(name):
	if '.pickle' in name:
		name = name[:-7]
	with open(name + ".pickle", "rb") as f:
		pickle_file = pickle.load(f)
	f.close()

	return pickle_file

def read_labels(f):
	file = open(f)
	top_labels = list()
	for line in file:
		top_labels.append(line[:-1])

	return top_labels
labels = read_labels('/content/62_previous_host_labels.txt')

for label in labels:
  print(label)
# Out:
# Nitrosative Stress
# Fermented Foods and Beverages
# Gestational Weight Gain
# Antineoplastic Agents, Immunological
# Sustainable Development
# Oligodendrocyte Precursor Cells
# Healthy Aging
# Marijuana Use
# Salpingo-oophorectomy
# Long-Acting Reversible Contraception
# Patient Health Questionnaire
# Platelet-Rich Fibrin
# Circulating Tumor DNA
# Nephroureterectomy
# PC-3 Cells
# Carbapenem-Resistant Enterobacteriaceae
# Receptors, Chimeric Antigen
# Procalcitonin
# Radiofrequency Ablation
# Proteostasis
# Dietary Sugars
# Tobacco Smoking
# Flexural Strength
# Deep Learning
# Mental Status and Dementia Tests
# Whole Genome Sequencing
# Liquid Biopsy
# Cigarette Smoking
# Work Engagement
# Mycobacterium abscessus
# Smokers
# Frailty
# Wildfires
# Mice, Knockout, ApoE
# Whole Exome Sequencing
# THP-1 Cells
# Saline Solution
# Greenhouse Gases
# Circulating MicroRNA
# Progression-Free Survival
# Anti-Citrullinated Protein Antibodies
# Treatment Adherence and Compliance
# Pyrolysis
# Nutrients
# Sexual Health
# Pain, Procedural
# Dietary Exposure
# Academic Performance
# Latent Class Analysis
# Cancer Survivors
# Gait Analysis
# Extracellular Polymeric Substance Matrix
# Antimicrobial Stewardship
# Shift Work Schedule
# Density Functional Theory
# Host Microbial Interactions
# Vaccination Coverage
# Water Pipe Smoking
# Salt Stress
# Intraepithelial Lymphocytes
# Adverse Childhood Experiences
# Composting

# %%
final_similarities=dict()
for j in os.listdir('/content/'):
  if 'from' in j:
    similarities= read_pickles('/content/'+j.split('.')[0])
    for key in similarities.keys():
      if (key in labels):
        if (key not in final_similarities.keys()):
          final_similarities[key] = list()
        for pair in similarities[key]:
          final_similarities[key].append(np.max(pair[0]))
      if (key == 'Flexural Strength'):
        print(len(final_similarities[key]))
# Out:
# 428
# 898
# 1310
# 1880
# 2410
# 2903
# 3480
# 3951
# 4515

# %%
import numpy as np
from sklearn import mixture
from sklearn.metrics import confusion_matrix

threshold_dict=dict()
count=0
clf = mixture.GaussianMixture(n_components=2, covariance_type='full', max_iter = 100, random_state = 24)
for key in final_similarities.keys():
  if (key in labels):
    print(key)
    X_train = np.array(final_similarities[key])
    clf.fit(X_train.reshape(-1,1))
    print(clf.means_ , '\nMidpoint value: ', np.round(np.mean(clf.means_),4))
    print()
    threshold_dict[key] = np.mean(clf.means_)
    count+=1


print(count)
# Out:
# Flexural Strength
# [[0.78355101]
#  [0.81797224]]
# Midpoint value:  0.8008
#
# Intraepithelial Lymphocytes
# [[0.8493362 ]
#  [0.83818161]]
# Midpoint value:  0.8438
#
# Nephroureterectomy
# [[0.78792746]
#  [0.81252173]]
# Midpoint value:  0.8002
#
# Water Pipe Smoking
# [[0.80214326]
#  [0.77917885]]
# Midpoint value:  0.7907
#
# Oligodendrocyte Precursor Cells
# [[0.88884809]
#  [0.85024986]]
# Midpoint value:  0.8695
#
# Mycobacterium abscessus
# [[0.8577915 ]
#  [0.89221257]]
# Midpoint value:  0.875
#
# Salpingo-oophorectomy
# [[0.88600643]
#  [0.83503665]]
# Midpoint value:  0.8605
#
# Long-Acting Reversible Contraception
# [[0.85152348]
#  [0.87916671]]
# Midpoint value:  0.8653
#
# Nitrosative Stress
# [[0.82982811]
#  [0.80988816]]
# Midpoint value:  0.8199
#
# Anti-Citrullinated Protein Antibodies
# [[0.87068751]
#  [0.86386102]]
# Midpoint value:  0.8673
#
# Extracellular Polymeric Substance Matrix
# [[0.85584563]
#  [0.83495124]]
# Midpoint value:  0.8454
#
# Proteostasis
# [[0.79351043]
#  [0.77976091]]
# Midpoint value:  0.7866
#
# Saline Solution
# [[0.77339931]
#  [0.80858439]]
# Midpoint value:  0.791
#
# Gestational Weight Gain
# [[0.83824954]
#  [0.79306578]]
# Midpoint value:  0.8157
#
# Wildfires
# [[0.78889797]
#  [0.77228582]]
# Midpoint value:  0.7806
#
# Receptors, Chimeric Antigen
# [[0.83172962]
#  [0.85527655]]
# Midpoint value:  0.8435
#
# Work Engagement
# [[0.77864232]
#  [0.73402376]]
# Midpoint value:  0.7563
#
# Sustainable Development
# [[0.73841902]
#  [0.76848713]]
# Midpoint value:  0.7535
#
# Procalcitonin
# [[0.7508145 ]
#  [0.78034863]]
# Midpoint value:  0.7656
#
# Pain, Procedural
# [[0.81422511]
#  [0.78277507]]
# Midpoint value:  0.7985
#
# Platelet-Rich Fibrin
# [[0.84182645]
#  [0.86250236]]
# Midpoint value:  0.8522
#
# Patient Health Questionnaire
# [[0.79471442]
#  [0.82789889]]
# Midpoint value:  0.8113
#
# Shift Work Schedule
# [[0.79717133]
#  [0.78149682]]
# Midpoint value:  0.7893
#
# PC-3 Cells
# [[0.82702682]
#  [0.8494199 ]]
# Midpoint value:  0.8382
#
# Treatment Adherence and Compliance
# [[0.83475163]
#  [0.86285437]]
# Midpoint value:  0.8488
#
# Salt Stress
# [[0.74168253]
#  [0.77599607]]
# Midpoint value:  0.7588
#
# Pyrolysis
# [[0.79402626]
#  [0.77828708]]
# Midpoint value:  0.7862
#
# Gait Analysis
# [[0.82872763]
#  [0.84397876]]
# Midpoint value:  0.8364
#
# Fermented Foods and Beverages
# [[0.84007896]
#  [0.86166413]]
# Midpoint value:  0.8509
#
# Mice, Knockout, ApoE
# [[0.81856227]
#  [0.84135948]]
# Midpoint value:  0.83
#
# Adverse Childhood Experiences
# [[0.7871101 ]
#  [0.76062515]]
# Midpoint value:  0.7739
#
# Liquid Biopsy
# [[0.79628959]
#  [0.81844397]]
# Midpoint value:  0.8074
#
# Host Microbial Interactions
# [[0.83697365]
#  [0.85602359]]
# Midpoint value:  0.8465
#
# Latent Class Analysis
# [[0.78882927]
#  [0.81348633]]
# Midpoint value:  0.8012
#
# Carbapenem-Resistant Enterobacteriaceae
# [[0.83360031]
#  [0.88830693]]
# Midpoint value:  0.861
#
# Circulating MicroRNA
# [[0.77206074]
#  [0.79494771]]
# Midpoint value:  0.7835
#
# Circulating Tumor DNA
# [[0.81180885]
#  [0.83841212]]
# Midpoint value:  0.8251
#
# Radiofrequency Ablation
# [[0.87889953]
#  [0.84896719]]
# Midpoint value:  0.8639
#
# Healthy Aging
# [[0.7886193 ]
#  [0.74153014]]
# Midpoint value:  0.7651
#
# Dietary Sugars
# [[0.84140641]
#  [0.81384107]]
# Midpoint value:  0.8276
#
# Density Functional Theory
# [[0.79715477]
#  [0.7529654 ]]
# Midpoint value:  0.7751
#
# Marijuana Use
# [[0.80938912]
#  [0.76812243]]
# Midpoint value:  0.7888
#
# Greenhouse Gases
# [[0.75675746]
#  [0.71757026]]
# Midpoint value:  0.7372
#
# Sexual Health
# [[0.74115254]
#  [0.76819107]]
# Midpoint value:  0.7547
#
# Dietary Exposure
# [[0.81814691]
#  [0.79619424]]
# Midpoint value:  0.8072
#
# Antimicrobial Stewardship
# [[0.84997123]
#  [0.80913168]]
# Midpoint value:  0.8296
#
# Tobacco Smoking
# [[0.74348988]
#  [0.77688614]]
# Midpoint value:  0.7602
#
# Academic Performance
# [[0.75449517]
#  [0.78474839]]
# Midpoint value:  0.7696
#
# Vaccination Coverage
# [[0.80632948]
#  [0.84530904]]
# Midpoint value:  0.8258
#
# Composting
# [[0.7662051 ]
#  [0.78146021]]
# Midpoint value:  0.7738
#
# Mental Status and Dementia Tests
# [[0.82603227]
#  [0.85773439]]
# Midpoint value:  0.8419
#
# Nutrients
# [[0.74118753]
#  [0.72352484]]
# Midpoint value:  0.7324
#
# Deep Learning
# [[0.72052521]
#  [0.76541805]]
# Midpoint value:  0.743
#
# Smokers
# [[0.77264848]
#  [0.75097797]]
# Midpoint value:  0.7618
#
# THP-1 Cells
# [[0.83403642]
#  [0.85612418]]
# Midpoint value:  0.8451
#
# Cigarette Smoking
# [[0.74667737]
#  [0.78293911]]
# Midpoint value:  0.7648
#
# Frailty
# [[0.78714717]
#  [0.81328961]]
# Midpoint value:  0.8002
#
# Progression-Free Survival
# [[0.81798385]
#  [0.85716797]]
# Midpoint value:  0.8376
#
# Whole Exome Sequencing
# [[0.8166867 ]
#  [0.78599356]]
# Midpoint value:  0.8013
#
# Antineoplastic Agents, Immunological
# [[0.86062768]
#  [0.87320034]]
# Midpoint value:  0.8669
#
# Cancer Survivors
# [[0.75413866]
#  [0.76423325]]
# Midpoint value:  0.7592
#
# Whole Genome Sequencing
# [[0.79904788]
#  [0.82267597]]
# Midpoint value:  0.8109
#
# 62

# %%
for key in threshold_dict:
  print(key)
  print(threshold_dict[key])
# Out:
# Flexural Strength
# 0.8007616272469859
# Intraepithelial Lymphocytes
# 0.8437589016569952
# Nephroureterectomy
# 0.8002245978435939
# Water Pipe Smoking
# 0.7906610534561063
# Oligodendrocyte Precursor Cells
# 0.8695489784148789
# Mycobacterium abscessus
# 0.8750020330100026
# Salpingo-oophorectomy
# 0.8605215401261901
# Long-Acting Reversible Contraception
# 0.8653450940342088
# Nitrosative Stress
# 0.819858136360166
# Anti-Citrullinated Protein Antibodies
# 0.8672742623412555
# Extracellular Polymeric Substance Matrix
# 0.8453984358456943
# Proteostasis
# 0.7866356650474866
# Saline Solution
# 0.7909918508023732
# Gestational Weight Gain
# 0.8156576583314405
# Wildfires
# 0.780591895752756
# Receptors, Chimeric Antigen
# 0.843503083831167
# Work Engagement
# 0.7563330423724477
# Sustainable Development
# 0.753453070957051
# Procalcitonin
# 0.7655815620075948
# Pain, Procedural
# 0.7985000919976066
# Platelet-Rich Fibrin
# 0.8521644082247817
# Patient Health Questionnaire
# 0.8113066547876386
# Shift Work Schedule
# 0.7893340730718572
# PC-3 Cells
# 0.8382233600125341
# Treatment Adherence and Compliance
# 0.8488029991124113
# Salt Stress
# 0.7588393041186006
# Pyrolysis
# 0.7861566695564617
# Gait Analysis
# 0.8363531945260811
# Fermented Foods and Beverages
# 0.8508715472169244
# Mice, Knockout, ApoE
# 0.8299608769109009
# Adverse Childhood Experiences
# 0.7738676242593434
# Liquid Biopsy
# 0.8073667820609854
# Host Microbial Interactions
# 0.8464986200109161
# Latent Class Analysis
# 0.8011577979241924
# Carbapenem-Resistant Enterobacteriaceae
# 0.8609536172955766
# Circulating MicroRNA
# 0.7835042259958722
# Circulating Tumor DNA
# 0.8251104841731931
# Radiofrequency Ablation
# 0.8639333585692863
# Healthy Aging
# 0.7650747161737033
# Dietary Sugars
# 0.8276237396213126
# Density Functional Theory
# 0.7750600895382551
# Marijuana Use
# 0.788755775264415
# Greenhouse Gases
# 0.7371638643199094
# Sexual Health
# 0.7546718077911153
# Dietary Exposure
# 0.8071705733458134
# Antimicrobial Stewardship
# 0.8295514581762502
# Tobacco Smoking
# 0.7601880082895225
# Academic Performance
# 0.7696217801065928
# Vaccination Coverage
# 0.8258192620883581
# Composting
# 0.7738326566071865
# Mental Status and Dementia Tests
# 0.8418833264924601
# Nutrients
# 0.7323561855846482
# Deep Learning
# 0.7429716266554078
# Smokers
# 0.7618132278117775
# THP-1 Cells
# 0.8450802955131327
# Cigarette Smoking
# 0.7648082389970987
# Frailty
# 0.8002183900066144
# Progression-Free Survival
# 0.8375759088791193
# Whole Exome Sequencing
# 0.8013401303274978
# Antineoplastic Agents, Immunological
# 0.8669140070641619
# Cancer Survivors
# 0.7591859580618856
# Whole Genome Sequencing
# 0.810861924400892

# %%
with open('gmms_threshold.pickle', 'wb') as f:
        pickle.dump(threshold_dict, f)
        f.close()
